# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('AuthorDataCitationsGrantsCSV.csv')

# %%
df.head()
# Out:
#    Year      Author            Institution         Country  \
# 0  2014  P. Stewart   University of Oxford  United Kingdom
# 1  2014   J. Frakes                    TMU          Canada
# 2  2014   L. Burton        York University          Canada
# 3  2014   D. Crosby        York University          Canada
# 4  2014     M. Dorn  University of Toronto          Canada
#
#                                   Research Interests  Citations  Grants
# 0  Turbulence, experimental fluid mechanics, lase...         48   25000
# 1  Modeling, analysis, control, and optimization ...         12    5000
# 2  Thermal sciences engineering education, lean m...         42    7400
# 3  Remote sensing of environmental flows, atmosph...         35   12000
# 4  Adaptive structures, structural health monitor...         18    9500

# %%
df.isnull().sum()
# Out:
# Year                  0
# Author                0
# Institution           0
# Country               0
# Research Interests    0
# Citations             0
# Grants                0
# dtype: int64

# %%
sns.boxplot(x=df['Grants'])
# Out:
# <Axes: xlabel='Grants'>

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(df['Institution'], df['Citations'])

# %%
df
